# %% [markdown]
# **Mental Health Prediction**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mental_health_wearable_data.csv.csv')

# %%
df.head()
# Out:
#    Heart_Rate_BPM  Sleep_Duration_Hours  Physical_Activity_Steps  Mood_Rating  \
# 0              98              7.425124                    13760            5
# 1             111              9.457572                    11455            9
# 2              88              4.037103                     9174            8
# 3              74              8.864101                    12612            1
# 4             102              9.690217                     3923            9
#
#    Mental_Health_Condition
# 0                        1
# 1                        0
# 2                        1
# 3                        1
# 4                        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Heart_Rate_BPM           10000 non-null  int64
#  1   Sleep_Duration_Hours     10000 non-null  float64
#  2   Physical_Activity_Steps  10000 non-null  int64
#  3   Mood_Rating              10000 non-null  int64
#  4   Mental_Health_Condition  10000 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 390.8 KB

# %%
df.columns
# Out:
# Index(['Heart_Rate_BPM', 'Sleep_Duration_Hours', 'Physical_Activity_Steps',
#        'Mood_Rating', 'Mental_Health_Condition'],
#       dtype='object')

# %%
df.describe().transpose()
# Out:
#                            count         mean          std          min  \
# Heart_Rate_BPM           10000.0    89.822000    17.309144    60.000000
# Sleep_Duration_Hours     10000.0     6.978495     1.730834     4.000317
# Physical_Activity_Steps  10000.0  8061.812000  4067.118120  1000.000000
# Mood_Rating              10000.0     5.065100     2.562522     1.000000
# Mental_Health_Condition  10000.0     0.515700     0.499778     0.000000
#
#                                  25%          50%           75%           max
# Heart_Rate_BPM             75.000000    90.000000    105.000000    119.000000
# Sleep_Duration_Hours        5.474809     6.951605      8.492401      9.998831
# Physical_Activity_Steps  4468.750000  8116.000000  11617.250000  14998.000000
# Mood_Rating                 3.000000     5.000000      7.000000      9.000000
# Mental_Health_Condition     0.000000     1.000000      1.000000      1.000000

# %%
df.isnull().sum()
# Out:
# Heart_Rate_BPM             0
# Sleep_Duration_Hours       0
# Physical_Activity_Steps    0
# Mood_Rating                0
# Mental_Health_Condition    0
# dtype: int64

# %%
df.value_counts()
# Out:
# Heart_Rate_BPM  Sleep_Duration_Hours  Physical_Activity_Steps  Mood_Rating  Mental_Health_Condition
# 60              4.034624              8353                     5            1                          1
# 100             5.634803              13615                    1            0                          1
#                 5.441363              4182                     1            1                          1
#                 5.443211              3446                     8            1                          1
#                 5.495772              6335                     1            1                          1
#                                                                                                       ..
# 80              6.617287              7579                     7            1                          1
#                 6.623690              9412                     1            1                          1
# ...

# %%
df.corr()
# Out:
#                          Heart_Rate_BPM  Sleep_Duration_Hours  \
# Heart_Rate_BPM                 1.000000             -0.024060
# Sleep_Duration_Hours          -0.024060              1.000000
# Physical_Activity_Steps       -0.003153             -0.008339
# Mood_Rating                   -0.006523              0.002620
# Mental_Health_Condition       -0.266143             -0.317829
#
#                          Physical_Activity_Steps  Mood_Rating  \
# Heart_Rate_BPM                         -0.003153    -0.006523
# Sleep_Duration_Hours                   -0.008339     0.002620
# Physical_Activity_Steps                 1.000000     0.003360
# Mood_Rating                             0.003360     1.000000
# Mental_Health_Condition                -0.007806     0.016811
#
#                          Mental_Health_Condition
# Heart_Rate_BPM                         -0.266143
# Sleep_Duration_Hours                   -0.317829
# Physical_Activity_Steps                -0.007806
# ...

# %% [markdown]
# *VISUALIZING THE DATA*

# %%
sns.pairplot(df[['Heart_Rate_BPM', 'Sleep_Duration_Hours', 'Physical_Activity_Steps','Mood_Rating', 'Mental_Health_Condition' ]],
             hue='Mental_Health_Condition',
             palette= ['#7bff61', '#ff61ab'])

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),cmap='magma',annot=True)
# Out:
# <Axes: >
